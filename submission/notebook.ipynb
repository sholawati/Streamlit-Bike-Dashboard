# %% [markdown]
# # Proyek Analisis Data: [Bike-sharing-dataset]
# - **Nama:** [Sholawati]
# - **Email:** [dema31874@gmail.com]
# - **ID Dicoding:** [sholawatii]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Kapan musim dengan jumlah penyewaan sepeda tertinggi?
# - Bagaimana pengaruh cuaca terhadap jumlah penyewaan sepeda?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
# Import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %%
# Import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#------------------------------Data Wrangling----------------------------------#

#Set style untuk visualisasi
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"]=(12,6)

#Load dataset
df = pd.read_csv('data/data_1.csv')

#Menampilkan 5 data teratas
print("5 Data teratas:")
print(df.head())

#Menampilkan jumlah baris dalam kolom
print("\nJumlah Baris dan kolom:")
print(df.shape)

#Menampilkan tipe data setiap kolom:
print("\nTipe data setiap kolom:")
print(df.dtypes)

#Mengecek missing values
print("\nJumlah missing value per kolom:")
print(df.isnull().sum())

# Ubah kolom tanggal menjadi tipe datetime
df['dteday'] = pd.to_datetime(df['dteday'])

#Ganti nama kolom agar lebih mudah dimengerti
df.rename(columns={
    'dteday': 'date',
    'yr': 'year',
    'mnth': 'month',
    'hum': 'humidity',
    'cnt': 'total_rentals',
    'atemp': 'feels_like',
    'weathersit': 'weather',
}, inplace=True)

#Ubah nilai numerik ke bentuk kategori yang lebih deskriptif
season_map = {
    1: 'Spring',
    2: 'Summer',
    3: 'Fall',
    4: 'Winter',
}

weather_map = {
    1: 'Clear',
    2: 'Mist/Cloudy',
    3: 'Light Rain/Snow',
    4: 'Heavy Rain/Snow'
}

#Mapping ke kolom terkait
df['season'] = df['season'].map(season_map)
df['weather'] = df['weather'].map(weather_map)

#Mapping nilai tahun agar lebih (0 = 2011, 1=2012)
df['yaer'] = df['year'].map({0: 2011, 1:2012})

#Cek hasil akhir pembersihan
print("5 Data teratas setelah wrangling:")
print(df.head())

print("\nTipe data terbaru")
print(df.dtypes)
# Out:
# 5 Data teratas:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
#
# Jumlah Baris dan kolom:
# (731, 16)
#
# Tipe data setiap kolom:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object
#
# Jumlah missing value per kolom:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64
# 5 Data teratas setelah wrangling:
#    instant       date  season  year  month  holiday  weekday  workingday  \
# 0        1 2011-01-01  Spring     0      1        0        6           0
# 1        2 2011-01-02  Spring     0      1        0        0           0
# 2        3 2011-01-03  Spring     0      1        0        1           1
# 3        4 2011-01-04  Spring     0      1        0        2           1
# 4        5 2011-01-05  Spring     0      1        0        3           1
#
#        weather      temp  feels_like  humidity  windspeed  casual  registered  \
# 0  Mist/Cloudy  0.344167    0.363625  0.805833   0.160446     331         654
# 1  Mist/Cloudy  0.363478    0.353739  0.696087   0.248539     131         670
# 2        Clear  0.196364    0.189405  0.437273   0.248309     120        1229
# 3        Clear  0.200000    0.212122  0.590435   0.160296     108        1454
# 4        Clear  0.226957    0.229270  0.436957   0.186900      82        1518
#
#    total_rentals  yaer
# 0            985  2011
# 1            801  2011
# 2           1349  2011
# 3           1562  2011
# 4           1600  2011
#
# Tipe data terbaru
# instant                   int64
# date             datetime64[ns]
# season                   object
# year                      int64
# month                     int64
# holiday                   int64
# weekday                   int64
# workingday                int64
# weather                  object
# temp                    float64
# feels_like              float64
# humidity                float64
# windspeed               float64
# casual                    int64
# registered                int64
# total_rentals             int64
# yaer                      int64
# dtype: object

# %% [markdown]
# ### Gathering Data

# %%
#Set style untuk visualisasi
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"]=(12,6)

#Load dataset
df = pd.read_csv('data/data_1.csv')

#Menampilkan 5 data teratas
print("5 Data teratas:")
print(df.head())

#Menampilkan jumlah baris dalam kolom
print("\nJumlah Baris dan kolom:")
print(df.shape)

#Menampilkan tipe data setiap kolom:
print("\nTipe data setiap kolom:")
print(df.dtypes)

#Mengecek missing values
print("\nJumlah missing value per kolom:")
print(df.isnull().sum())
# Out:
# 5 Data teratas:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
#
# Jumlah Baris dan kolom:
# (731, 16)
#
# Tipe data setiap kolom:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object
#
# Jumlah missing value per kolom:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# **Insight:**
# - Dataset terdiri dari 731 baris dan 16 kolom.
# - Tidak terdapat missing value di dalam dataset.
# - Kolom dteday berisi data tanggal dari tahun 2011 sampai 2012.
# - Data sudah cukup lengkap untuk dianalisis tanpa perlu imputasi nilai hilang.

# %% [markdown]
# ### Assessing Data

# %%
#Menampilkan jumlah baris dalam kolom
print("\nJumlah Baris dan kolom:")
print(df.shape)

#Menampilkan tipe data setiap kolom:
print("\nTipe data setiap kolom:")
print(df.dtypes)

#Mengecek missing values
print("\nJumlah missing value per kolom:")
print(df.isnull().sum())
# Out:
# Jumlah Baris dan kolom:
# (731, 16)
#
# Tipe data setiap kolom:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object
#
# Jumlah missing value per kolom:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# **Insight:**
# - Dataset terdiri dari 731 baris dan 16 kolom.
# - Tidak terdapat missing value di dalam dataset.
# - Kolom season, yr, mnth, dan weekday bebentuk numerik yang perlu dikonversi ke kategori agar lebih informatif.
# - Tidak ditemukan duplikasi data.

# %% [markdown]
# ### Cleaning Data

# %%
# Ubah kolom tanggal menjadi tipe datetime
df['dteday'] = pd.to_datetime(df['dteday'])

#Ganti nama kolom agar lebih mudah dimengerti
df.rename(columns={
    'dteday': 'date',
    'yr': 'year',
    'mnth': 'month',
    'hum': 'humidity',
    'cnt': 'total_rentals',
    'atemp': 'feels_like',
    'weathersit': 'weather',
}, inplace=True)

#Ubah nilai numerik ke bentuk kategori yang lebih deskriptif
season_map = {
    1: 'Spring',
    2: 'Summer',
    3: 'Fall',
    4: 'Winter',
}

weather_map = {
    1: 'Clear',
    2: 'Mist/Cloudy',
    3: 'Light Rain/Snow',
    4: 'Heavy Rain/Snow'
}

#Mapping ke kolom terkait
df['season'] = df['season'].map(season_map)
df['weather'] = df['weather'].map(weather_map)

#Mapping nilai tahun agar lebih (0 = 2011, 1=2012)
df['yaer'] = df['year'].map({0: 2011, 1:2012})

#Cek hasil akhir pembersihan
print("5 Data teratas setelah wrangling:")
print(df.head())

print("\nTipe data terbaru")
print(df.dtypes)
# Out:
# 5 Data teratas setelah wrangling:
#    instant       date  season  year  month  holiday  weekday  workingday  \
# 0        1 2011-01-01  Spring     0      1        0        6           0
# 1        2 2011-01-02  Spring     0      1        0        0           0
# 2        3 2011-01-03  Spring     0      1        0        1           1
# 3        4 2011-01-04  Spring     0      1        0        2           1
# 4        5 2011-01-05  Spring     0      1        0        3           1
#
#        weather      temp  feels_like  humidity  windspeed  casual  registered  \
# 0  Mist/Cloudy  0.344167    0.363625  0.805833   0.160446     331         654
# 1  Mist/Cloudy  0.363478    0.353739  0.696087   0.248539     131         670
# 2        Clear  0.196364    0.189405  0.437273   0.248309     120        1229
# 3        Clear  0.200000    0.212122  0.590435   0.160296     108        1454
# 4        Clear  0.226957    0.229270  0.436957   0.186900      82        1518
#
#    total_rentals  yaer
# 0            985  2011
# 1            801  2011
# 2           1349  2011
# 3           1562  2011
# 4           1600  2011
#
# Tipe data terbaru
# instant                   int64
# date             datetime64[ns]
# season                   object
# year                      int64
# month                     int64
# holiday                   int64
# weekday                   int64
# workingday                int64
# weather                  object
# temp                    float64
# feels_like              float64
# humidity                float64
# windspeed               float64
# casual                    int64
# registered                int64
# total_rentals             int64
# yaer                      int64
# dtype: object

# %% [markdown]
# **Insight:**
# - Kolom yang tidak relevan seperti instant, dteday, casual, dan registered telah dihapus untuk menyederhanakan analisis.
# - Kolom kategorikal seperti season, yr, mnth, holiday, weekday, workingday, dan weathersit telah dikonversi ke tipe kategori agar lebbih representatif.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
# Import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#------------------------------Data Wrangling----------------------------------#

#Set style untuk visualisasi
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"]=(12,6)

#Load dataset
df = pd.read_csv('data/data_1.csv')

#Menampilkan 5 data teratas
print("5 Data teratas:")
print(df.head())

#Menampilkan jumlah baris dalam kolom
print("\nJumlah Baris dan kolom:")
print(df.shape)

#Menampilkan tipe data setiap kolom:
print("\nTipe data setiap kolom:")
print(df.dtypes)

#Mengecek missing values
print("\nJumlah missing value per kolom:")
print(df.isnull().sum())

# Ubah kolom tanggal menjadi tipe datetime
df['dteday'] = pd.to_datetime(df['dteday'])

#Ganti nama kolom agar lebih mudah dimengerti
df.rename(columns={
    'dteday': 'date',
    'yr': 'year',
    'mnth': 'month',
    'hum': 'humidity',
    'cnt': 'total_rentals',
    'atemp': 'feels_like',
    'weathersit': 'weather',
}, inplace=True)

#Ubah nilai numerik ke bentuk kategori yang lebih deskriptif
season_map = {
    1: 'Spring',
    2: 'Summer',
    3: 'Fall',
    4: 'Winter',
}

weather_map = {
    1: 'Clear',
    2: 'Mist/Cloudy',
    3: 'Light Rain/Snow',
    4: 'Heavy Rain/Snow'
}

#Mapping ke kolom terkait
df['season'] = df['season'].map(season_map)
df['weather'] = df['weather'].map(weather_map)

#Mapping nilai tahun agar lebih (0 = 2011, 1=2012)
df['yaer'] = df['year'].map({0: 2011, 1:2012})

#Cek hasil akhir pembersihan
print("5 Data teratas setelah wrangling:")
print(df.head())

print("\nTipe data terbaru")
print(df.dtypes)

#----------------------Exploratory Data Analysis (EDA)-------------------------#

#Statistik deskriptif dasar
print("Satistik Deskriptif:")
print(df[['total_rentals','humidity','temp','feels_like','windspeed']].describe)

#Nilai median dan modus
print("\nMedian jumlah penyewaan:", df['total_rentals'].median())
print("Modus jumlah penyewaan:", df['total_rentals'].mode()[0])

#Rata-rata penyewaan perbulan(gabungan 2011 dan 2012)
monthly_avg = df.groupby('month')['total_rentals'].mean()

#Plot
sns.lineplot(x=monthly_avg.index, y=monthly_avg.values, marker='o')
plt.title('Rara-rata penyewaan sepeda per bulan')
plt.xlabel('Bulan')
plt.ylabel('Rata-rata penyewaan')
plt.xticks(ticks=range(1,13), labels=[
    'Jan', 'Feb', 'Mar', 'Apr', 'Mei', 'Jun',
    'Jul', 'Agu', 'Sep', 'Okt', 'Nov', 'Des'
])
plt.show()

#Rata-rata penyewaan per musim
season_avg = df.groupby('season')['total_rentals'].mean().sort_values(ascending=False)

#plot
sns.barplot(
    x=season_avg.index,
    y=season_avg.values,
    hue=season_avg.index,
    palette='coolwarm',
    legend=False
    )
plt.title('Rata-rata penyewaan sepeda per musim')
plt.xlabel('Musim')
plt.ylabel('Rata-rata Penyewaan')
plt.show()

#Boxplot penyewaan berdasarkan cuaca
sns.boxplot(
    x='weather',
    y='total_rentals',
    hue='weather',
    data=df,
    palette='Set2',
    legend=False
    )
plt.title('Distribusi jumlah penyewaan berdasarkan kondisi cuaca')
plt.xlabel('kondisi cuaca')
plt.ylabel('jumlah penyewaan')
plt.xticks(rotation=15)
plt.show()
# Out:
# 5 Data teratas:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
#
# Jumlah Baris dan kolom:
# (731, 16)
#
# Tipe data setiap kolom:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object
#
# Jumlah missing value per kolom:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64
# 5 Data teratas setelah wrangling:
#    instant       date  season  year  month  holiday  weekday  workingday  \
# 0        1 2011-01-01  Spring     0      1        0        6           0
# 1        2 2011-01-02  Spring     0      1        0        0           0
# 2        3 2011-01-03  Spring     0      1        0        1           1
# 3        4 2011-01-04  Spring     0      1        0        2           1
# 4        5 2011-01-05  Spring     0      1        0        3           1
#
#        weather      temp  feels_like  humidity  windspeed  casual  registered  \
# 0  Mist/Cloudy  0.344167    0.363625  0.805833   0.160446     331         654
# 1  Mist/Cloudy  0.363478    0.353739  0.696087   0.248539     131         670
# 2        Clear  0.196364    0.189405  0.437273   0.248309     120        1229
# 3        Clear  0.200000    0.212122  0.590435   0.160296     108        1454
# 4        Clear  0.226957    0.229270  0.436957   0.186900      82        1518
#
#    total_rentals  yaer
# 0            985  2011
# 1            801  2011
# 2           1349  2011
# 3           1562  2011
# 4           1600  2011
#
# Tipe data terbaru
# instant                   int64
# date             datetime64[ns]
# season                   object
# year                      int64
# month                     int64
# holiday                   int64
# weekday                   int64
# workingday                int64
# weather                  object
# temp                    float64
# feels_like              float64
# humidity                float64
# windspeed               float64
# casual                    int64
# registered                int64
# total_rentals             int64
# yaer                      int64
# dtype: object
# Satistik Deskriptif:
# <bound method NDFrame.describe of      total_rentals  humidity      temp  feels_like  windspeed
# 0              985  0.805833  0.344167    0.363625   0.160446
# 1              801  0.696087  0.363478    0.353739   0.248539
# 2             1349  0.437273  0.196364    0.189405   0.248309
# 3             1562  0.590435  0.200000    0.212122   0.160296
# 4             1600  0.436957  0.226957    0.229270   0.186900
# ..             ...       ...       ...         ...        ...
# 726           2114  0.652917  0.254167    0.226642   0.350133
# 727           3095  0.590000  0.253333    0.255046   0.155471
# 728           1341  0.752917  0.253333    0.242400   0.124383
# 729           1796  0.483333  0.255833    0.231700   0.350754
# 730           2729  0.577500  0.215833    0.223487   0.154846
#
# [731 rows x 5 columns]>
#
# Median jumlah penyewaan: 4548.0
# Modus jumlah penyewaan: 1096

# %% [markdown]
# **Insight:**
# - Jumlah penyewaan sepeda tertinggi terjadi pada musim gugr (Fall), menunjukkan bahwa musim ini adalah periode paling aktif untuk pengguna.
# - Penggunaan sepeda menurun drastis saat kondisi cuaca buruk, terutama saat hujan/salju, dan paling tinggi saat cuaca cerah.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
# Grouping penyewaan permusim
import seaborn as sn
import matplotlib.pyplot as plt

#Rata-rata penyewaan per musim
season_avg = df.groupby('season')['total_rentals'].mean().sort_values(ascending=False)

#plot
sns.barplot(
    x=season_avg.index,
    y=season_avg.values,
    hue=season_avg.index,
    palette='coolwarm',
    legend=False
    )
plt.title('Rata-rata penyewaan sepeda per musim')
plt.xlabel('Musim')
plt.ylabel('Rata-rata Penyewaan')
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
#Boxplot distribusi penyewaan berdasarkan cuaca
sns.boxplot(
    x='weather',
    y='total_rentals',
    hue='weather',
    data=df,
    palette='Set2',
    legend=False
    )
plt.title('Distribusi jumlah penyewaan berdasarkan kondisi cuaca')
plt.xlabel('kondisi cuaca')
plt.ylabel('jumlah penyewaan')
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# **Insight:**
# - Jumlah penyewaan sepeda tertinggi terjadi pada musim Fall(Gugur), menunjukkan musim ini sebagai waktu paling aktif bagi pengguna.
# - Penyewaan sepeda jauh lebih tinggi saat cuaca cerah, dan menurun tajam saat hujan atau salju lebat, menunjukkan pengaruh signifikan dari kondisi cuaca.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Pada musim gugur(Fall), rata-rata jumlah penyewaan sepeda mencapai puncaknya. Ini menunjukkan bahwa pengguna lebih aktif menggunakan sepeda di musim ini, kemungkinan karena cuaca yang nyaman dan kondisi jalan yang mendukung.
# - Cuaca memiliki pengaruh besar terhadap penyewaan sepeda. Cuaca cerah mendorong jumlah penyewaan yang tinggi, sementara cuaca buruk seperti hujn atau salju menyebabkan penurunan tajam dalam aktivitas penyewaan.

# %% [markdown]
# ### Menyimpan Hasil ke main_data.csv

# %%
# Menyimpan data yang telah dibersihkan ke dashboard/main_data.csv
df.to_csv('dashboard/main_data.csv', index=False)
print("Data berhasil disimpan ke 'dashboard/main_data.csv'")
# Out:
# Data berhasil disimpan ke 'dashboard/main_data.csv'
